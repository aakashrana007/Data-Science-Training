# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashrana007/Data-Science-Training/blob/main/DAY9_More_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classwork - Pandas
# 1. Load a dataset (e.g., a CSV file) into a Pandas DataFrame.
# 2. Check the first few rows of the dataset to understand its structure.
# 3. Check the shape of the dataset to see how many rows and columns it has.
# 4. Check the data types of each column in the DataFrame.
# 5. Check for missing values in the dataset and handle them appropriately.
# 6. Filter the dataset to only include rows that meet specific criteria (e.g., where a certain column is greater than a certain value).
# 7. Calculate descriptive statistics for numerical columns in the dataset.
# 8. Group the data based on a specific column and calculate summary statistics for each group.
# 9. Create new columns in the DataFrame based on existing columns (e.g., calculate a new column by applying a function to existing columns).
# 10. Merge/join multiple datasets together based on a common column.
# 11. Identify the top 5 rows with the highest values in a specific column and display only those rows.
# 12. Count the frequency of unique values in a categorical column and visualize the results using a bar chart and pie chart.
# 13. Calculate the average value of a numerical column based on another categorical column's values.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
test=pd.read_csv('/content/drive/MyDrive/data/tested.csv')
test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
test.shape
# Out:
# (418, 12)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
test.isnull() #check for missing values
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
filt_age= (test['Age']>18) & (test['Sex']== 'male')
filt_age
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413    False
# 414    False
# 415     True
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
test.loc[filt_age]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 2            894         0       2
# 3            895         0       3
# 7            899         0       2
# 9            901         0       3
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 406         1298         0       2
# 407         1299         0       1
# 415         1307         0       3
#
#                                              Name   Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  male  34.5      0      0
# 2                       Myles, Mr. Thomas Francis  male  62.0      0      0
# 3                                Wirz, Mr. Albert  male  27.0      0      0
# 7                    Caldwell, Mr. Albert Francis  male  26.0      1      1
# 9                         Davies, Mr. John Samuel  male  21.0      2      0
# ..                                            ...   ...   ...    ...    ...
# ...

# %%
test.loc[filt_age,['Age']].mean()
# Out:
# Age    33.48
# dtype: float64

# %%
test.loc[filt_age,['Age']].median()
# Out:
# Age    30.0
# dtype: float64

# %%
#create a new column with sibling and parents added
test['Family_mem']=test['SibSp']+test['Parch']
test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Identify the top 5 rows with the highest values in age and display only those rows.
test.nlargest(5,'Age')
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 179         1071         1       1
# 236         1128         0       1
# 305         1197         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
#
#      Parch    Ticket      Fare    Cabin Embarked  Family_mem
# 96       0     19877   78.8500      C46        S           1
# 81       0  PC 17483  221.7792  C55 C57        S           1
# 179      2  PC 17756   83.1583      E45        C           2
# ...

# %%
test.value_counts('Sex')
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
test['Sex'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
test.value_counts('Age').plot(kind='barh')
# Out:
# <Axes: ylabel='Age'>
