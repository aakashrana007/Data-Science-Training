# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashrana007/Data-Science-Training/blob/main/Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
data = px.data.gapminder()    #px.data have some ore built set of dataset
#Gapminder dataset, which includes data about various countries, such as their population,
# GDP per capita, and life expectancy over the years.
data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
px.scatter(data,
           x="gdpPercap",
           y="lifeExp",
           animation_frame="year",
           animation_group="country",
           size="pop",
           color="country",
           hover_name="country",
           log_x=True,
           size_max=55,
           range_x=[100,100000],
           range_y=[25,90]
          )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > Filter dataset from Nepal

# %%
df_nepal= data[data['country']=='Nepal']
df_nepal
# Out:
#      country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1068   Nepal      Asia  1952   36.157   9182536   545.865723       NPL
# 1069   Nepal      Asia  1957   37.686   9682338   597.936356       NPL
# 1070   Nepal      Asia  1962   39.393  10332057   652.396859       NPL
# 1071   Nepal      Asia  1967   41.472  11261690   676.442225       NPL
# 1072   Nepal      Asia  1972   43.971  12412593   674.788130       NPL
# 1073   Nepal      Asia  1977   46.748  13933198   694.112440       NPL
# 1074   Nepal      Asia  1982   49.594  15796314   718.373095       NPL
# 1075   Nepal      Asia  1987   52.537  17917180   775.632450       NPL
# 1076   Nepal      Asia  1992   55.727  20326209   897.740360       NPL
# 1077   Nepal      Asia  1997   59.426  23001113  1010.892138       NPL
# 1078   Nepal      Asia  2002   61.340  25873917  1057.206311       NPL
# 1079   Nepal      Asia  2007   63.785  28901790  1091.359778       NPL
#
#       iso_num
# 1068      524
# ...

# %% [markdown]
# #OR

# %%
df_nepal=data.query("country=='Nepal'")
df_nepal
# Out:
#      country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1068   Nepal      Asia  1952   36.157   9182536   545.865723       NPL
# 1069   Nepal      Asia  1957   37.686   9682338   597.936356       NPL
# 1070   Nepal      Asia  1962   39.393  10332057   652.396859       NPL
# 1071   Nepal      Asia  1967   41.472  11261690   676.442225       NPL
# 1072   Nepal      Asia  1972   43.971  12412593   674.788130       NPL
# 1073   Nepal      Asia  1977   46.748  13933198   694.112440       NPL
# 1074   Nepal      Asia  1982   49.594  15796314   718.373095       NPL
# 1075   Nepal      Asia  1987   52.537  17917180   775.632450       NPL
# 1076   Nepal      Asia  1992   55.727  20326209   897.740360       NPL
# 1077   Nepal      Asia  1997   59.426  23001113  1010.892138       NPL
# 1078   Nepal      Asia  2002   61.340  25873917  1057.206311       NPL
# 1079   Nepal      Asia  2007   63.785  28901790  1091.359778       NPL
#
#       iso_num
# 1068      524
# ...

# %%
px.bar(df_nepal, x='year', y='pop')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.line(df_nepal, x='year',y='pop')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_asia = data.query("continent=='Asia'")
df_asia
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106       AFG
# ...           ...       ...   ...      ...       ...          ...       ...
# 1675  Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538       YEM
# 1676  Yemen, Rep.      Asia  1992   55.599  13367997  1879.496673       YEM
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526       YEM
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257  2234.820827       YEM
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906       YEM
#
#       iso_num
# 0           4
# 1           4
# ...

# %%
px.line(df_asia, x='year', y='lifeExp', color='country')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_europe=data.query("continent=='Europe'")
df_europe
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  \
# 12           Albania    Europe  1952   55.230   1282697   1601.056136
# 13           Albania    Europe  1957   59.280   1476505   1942.284244
# 14           Albania    Europe  1962   64.820   1728137   2312.888958
# 15           Albania    Europe  1967   66.220   1984060   2760.196931
# 16           Albania    Europe  1972   67.690   2263554   3313.422188
# ...              ...       ...   ...      ...       ...           ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280
#
#      iso_alpha  iso_num
# 12         ALB        8
# 13         ALB        8
# 14         ALB        8
# 15         ALB        8
# ...

# %%
px.line(df_europe, x='year', y='lifeExp', color='country')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#to color country Albania only out of all other countries from df_europe
px.line(df_europe, x='year', y='lifeExp',color='country', color_discrete_map={'Turkey':'black'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Plot countries based on selected names: say canada and nepal

# %%
df_filter=data.query("country in ['Canada','Nepal']")
df_filter
# Out:
#      country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 240   Canada  Americas  1952   68.750  14785584  11367.161120       CAN
# 241   Canada  Americas  1957   69.960  17010154  12489.950060       CAN
# 242   Canada  Americas  1962   71.300  18985849  13462.485550       CAN
# 243   Canada  Americas  1967   72.130  20819767  16076.588030       CAN
# 244   Canada  Americas  1972   72.880  22284500  18970.570860       CAN
# 245   Canada  Americas  1977   74.210  23796400  22090.883060       CAN
# 246   Canada  Americas  1982   75.760  25201900  22898.792140       CAN
# 247   Canada  Americas  1987   76.860  26549700  26626.515030       CAN
# 248   Canada  Americas  1992   77.950  28523502  26342.884260       CAN
# 249   Canada  Americas  1997   78.610  30305843  28954.925890       CAN
# 250   Canada  Americas  2002   79.770  31902268  33328.965070       CAN
# 251   Canada  Americas  2007   80.653  33390141  36319.235010       CAN
# ...

# %%
"""fig = px.line(df_filter, x="lifeExp", y="gdpPercap", color="country", text="year")
fig.update_traces(textposition="bottom right")
fig.show()"""

#OR

px.line(df_filter, x='lifeExp',y='gdpPercap',color='country',text='year').update_traces(textposition='bottom right')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Nepal vs India

# %%
df_nepind=data.query("country in ['Nepal','India']")
fig=px.scatter(df_nepind, x='lifeExp', y='gdpPercap',color='country',text='pop')
fig.update_traces(textposition='bottom right')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Create a function `compare_countries` that produces similar chart comparing two countries.
# Eg: `compare_countries('India','Nepal')`

# %%
def compare_countries(country1,country2):
  df_country=data.query(f"country in ['{country1}','{country2}']")
  fig=px.line(df_country, x='lifeExp', y='gdpPercap',color='country',text='pop')
  fig.update_traces(textposition='bottom right')
  fig.show()

compare_countries('China','India')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=px.data.tips()
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
px.box(df, y='total_bill')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
geojson=px.data.election_geojson()
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-73.6363215300962, 45.5759177646435],
#        [-73.6362833815582, 45.5758266113331],
#        [-73.6446417578686, 45.5658132919643],
#        [-73.6453511352974, 45.5647725775888],
#        [-73.648867564748, 45.5586898267402],
#        [-73.6513170845065, 45.5545659435652],
#        [-73.6515658357324, 45.5554439857955],
#        [-73.6660837831645, 45.5596724837829],
#        [-73.6706609041685, 45.5610978251999],
#        [-73.6676019919116, 45.5632340862888],
#        [-73.6645385824068, 45.5642716484367],
#        [-73.663663123697, 45.5654269638586],
#        [-73.663336397858, 45.5666288247853],
#        [-73.6637764768649, 45.5678900619231],
#        [-73.6625073244826, 45.5688479494114],
#        [-73.6624620526633, 45.5708304456346],
#        [-73.6620201425015, 45.5713925326191],
#        [-73.6616100197742, 45.5737924780218],
# ...

# %%
df_elec=px.data.election()
df_elec
# Out:
#                                              district  Coderre  Bergeron  \
# 0                                  101-Bois-de-Liesse     2481      1829
# 1                               102-Cap-Saint-Jacques     2525      1163
# 2                                11-Sault-au-Récollet     3348      2770
# 3                                        111-Mile-End     1734      4782
# 4                                      112-DeLorimier     1770      5933
# 5                                    113-Jeanne-Mance     1455      3599
# 6                                    12-Saint-Sulpice     3252      2521
# 7                          121-La Pointe-aux-Prairies     5456      1760
# 8                             122-Pointe-aux-Trembles     4734      1879
# 9                            123-Rivière-des-Prairies     5737       958
# 10                                        13-Ahuntsic     2979      3430
# 11                                  131-Saint-Édouard     1827      6408
# ...

# %% [markdown]
# #Geojson
#
# GeoJSON is a format for encoding a variety of geographic data structures using JavaScript Object Notation (JSON). Plotly, a graphing library for Python and other programming languages, supports GeoJSON for creating geographic visualizations, such as maps with markers, polygons, and other geographical features.

# %%
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(df,
                           geojson=geojson,
                           color="Joly",
                           locations="district",
                           featureidkey="properties.district",
                           center={"lat": 45.5517, "lon": -73.7073},
                           mapbox_style="carto-positron",
                           zoom=9)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter_geo(df,
                     locations="iso_alpha",
                     color="continent",
                     hover_name="country",
                     size="pop",
                     animation_frame="year",
                     projection="natural earth"
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
