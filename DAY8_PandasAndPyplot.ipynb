# %% [markdown]
# <a href="https://colab.research.google.com/github/aakashrana007/Data-Science-Training/blob/main/DAY8_PandasAndPyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/data/survey_results_public.csv')
schema_df=pd.read_csv('/content/drive/MyDrive/data/survey_results_schema.csv',index_col='Column')

# %%
df['Respondent'].value_counts()
# Out:
# Respondent
# 1        1
# 59630    1
# 59638    1
# 59637    1
# 59636    1
#         ..
# 29802    1
# 29801    1
# 29800    1
# 29799    1
# 88863    1
# Name: count, Length: 88883, dtype: int64

# %%
df.value_counts('Country')
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# > Filter respondents from Nepal

# %%
df['Country'] == 'Nepal'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %% [markdown]
# >So how many from Nepal? Above code returns False and True

# %%
(df['Country'] == 'Nepal').value_counts()
# Out:
# Country
# False    88646
# True       237
# Name: count, dtype: int64

# %% [markdown]
# >Getting Nepal Dataframe
#
# **Use-**
# To select Criteria

# %%
df[df['Country'] == 'Nepal']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %%
filt_Nepal=df['Country'] == 'Nepal'
filt_Nepal
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Name: Country, Length: 88883, dtype: bool

# %% [markdown]
# >Another way through *loc*
#
# (To see the Nepal dataframe)

# %% [markdown]
# single df= returns True or False
#
# double cd= returns Data Frame

# %%
df.loc[filt_Nepal]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 506           508  I am a student who is learning to code      Yes
# 589           592          I am a developer by profession      Yes
# 980           984          I am a developer by profession      Yes
# 1348         1355          I am a developer by profession      Yes
# 1775         1783          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 86082       86618          I am a developer by profession      Yes
# 86205       86742          I am a developer by profession      Yes
# 86691       87231          I am a developer by profession      Yes
# 87026       87568          I am a developer by profession      Yes
# 87994       88543          I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 506                                                Never
# ...

# %% [markdown]
# >Check the *MgrIdiot* of Nepali People

# %%
df.loc[filt_Nepal, 'MgrIdiot']
# Out:
# 506                         NaN
# 589                         NaN
# 980          Somewhat confident
# 1348         Somewhat confident
# 1775       Not at all confident
#                   ...
# 86082      Not at all confident
# 86205        Somewhat confident
# 86691    I don't have a manager
# 87026        Somewhat confident
# 87994        Somewhat confident
# Name: MgrIdiot, Length: 237, dtype: object

# %%
(df.loc[filt_Nepal, 'MgrIdiot']).value_counts()   #filters out the numbers of people choosing options
# Out:
# MgrIdiot
# Somewhat confident        66
# Very confident            28
# Not at all confident      23
# I don't have a manager     9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# >BAR CHART

# %%
df.loc[filt_Nepal, 'MgrIdiot'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='MgrIdiot'>

# %% [markdown]
# >PIE CHART

# %%
df.loc[filt_Nepal, 'MgrIdiot'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# >Using *&* operator for 'multiple queries'

# %% [markdown]
# To check How many people in nepal think their manager is actually idiot. Or check who says Not at all Confident to their manager

# %%
filt_idiot= (df['Country'] == 'Nepal') & (df['MgrIdiot'] == 'Not at all confident')
filt_idiot.value_counts()
# Out:
# False    88860
# True        23
# Name: count, dtype: int64

# %%
df.loc[filt_idiot]    #returns the dataframe or manually use double df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 1775         1783  I am a developer by profession      Yes
# 4431         4452  I am a developer by profession      Yes
# 8354         8392  I am a developer by profession       No
# 8713         8751  I am a developer by profession      Yes
# 9819         9860  I am a developer by profession      Yes
# 12165       12222  I am a developer by profession      Yes
# 16410       16498  I am a developer by profession      Yes
# 25834       25984  I am a developer by profession      Yes
# 28988       29157  I am a developer by profession      Yes
# 32415       32610  I am a developer by profession      Yes
# 40357       40608  I am a developer by profession      Yes
# 40855       41114  I am a developer by profession      Yes
# 51711       52045  I am a developer by profession      Yes
# 60109       60493  I am a developer by profession      Yes
# 60774       61164     I code primarily as a hobby      Yes
# ...

# %%
df.loc[filt_idiot,['ConvertedComp']]    #returns salary of people thinking manager idiot(filt_idiot)
# Out:
#        ConvertedComp
# 1775          1692.0
# 4431             NaN
# 8354             NaN
# 8713             NaN
# 9819             NaN
# 12165            NaN
# 16410         1584.0
# 25834            NaN
# 28988         6852.0
# 32415         6324.0
# 40357         3168.0
# 40855         4992.0
# 51711         8436.0
# 60109            NaN
# 60774            NaN
# 63246            NaN
# 67858         4224.0
# 70321            NaN
# 73235         2220.0
# 78602         8788.0
# 81469         5268.0
# 84422         3696.0
# 86082        12000.0

# %%
df.loc[filt_idiot,['ConvertedComp']].median()
# Out:
# ConvertedComp    4992.0
# dtype: float64

# %%
df.loc[filt_idiot,['ConvertedComp']].mean()
# Out:
# ConvertedComp    5326.461538
# dtype: float64

# %% [markdown]
# ##ClassWork
# Welcome change?
#
# Extract the *QuestionText* of the index called *WelcomeChange* from *schema_df*.
#
# Display the *WelcomeChange* column from original dataframe df.
#
# From our original dataframe *df*, find the *value_counts()* of *WelcomeChange*
#
# Show the bar graph plot

# %%
schema_df.loc['WelcomeChange','QuestionText']   #returns the question of WelcomeChange row from dataset schema_df
# Out:
# 'Compared to last year, how welcome do you feel on Stack Overflow?'

# %%
df['WelcomeChange']   #returns the column WelcomeChange from data set df
# Out:
# 0         Just as welcome now as I felt last year
# 1         Just as welcome now as I felt last year
# 2         Just as welcome now as I felt last year
# 3         Just as welcome now as I felt last year
# 4         Just as welcome now as I felt last year
#                            ...
# 88878                                         NaN
# 88879                                         NaN
# 88880                                         NaN
# 88881                                         NaN
# 88882    Somewhat less welcome now than last year
# Name: WelcomeChange, Length: 88883, dtype: object

# %%
df['WelcomeChange'].value_counts()  #returns the value_counts of WelcomeChange column from data set df
# Out:
# WelcomeChange
# Just as welcome now as I felt last year                    62661
# Somewhat more welcome now than last year                    8853
# A lot more welcome now than last year                       4808
# Somewhat less welcome now than last year                    4259
# Not applicable - I did not use Stack Overflow last year     2675
# A lot less welcome now than last year                       2599
# Name: count, dtype: int64

# %%
df['WelcomeChange'].value_counts().plot(kind='bar',ylabel='Count',
    xlabel='Welcome Change Data')  #returns the bar graph plot of WelcomeChange column from data set df
# Out:
# <Axes: xlabel='Welcome Change Data', ylabel='Count'>

# %% [markdown]
# # High salary Nepalese
# Doing multiple queries?
#
# Filter the respondents who are from Nepal and whose salary is greater than 10000. (Hint: *ConvertedComp* column.)
#
# What is their *Employment* type and display their value_counts? (Hint: Column name is *Employment*)

# %%
filt_senior= (df['Country'] == 'Nepal') & (df['ConvertedComp'] > 10000)  #returns True or False
filt_senior
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88878    False
# 88879    False
# 88880    False
# 88881    False
# 88882    False
# Length: 88883, dtype: bool

# %%
df.loc[filt_senior,['Employment']]  #returns the Employment column from data set df
# Out:
#                                               Employment
# 5968   Independent contractor, freelancer, or self-em...
# 25114  Independent contractor, freelancer, or self-em...
# 25897                                 Employed full-time
# 39282  Independent contractor, freelancer, or self-em...
# 40383                                 Employed full-time
# 42801  Independent contractor, freelancer, or self-em...
# 54821                                 Employed full-time
# 61281                                 Employed full-time
# 63428                                 Employed full-time
# 77455                                 Employed full-time
# 78532                                 Employed full-time
# 81604                                 Employed full-time
# 84918  Independent contractor, freelancer, or self-em...
# 86082                                 Employed full-time

# %%
df[filt_senior]['Employment'].value_counts()  #returns the value_counts of Employment column from data set df
# Out:
# Employment
# Employed full-time                                      9
# Independent contractor, freelancer, or self-employed    5
# Name: count, dtype: int64
